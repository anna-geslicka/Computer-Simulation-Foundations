# %%
def draw_lissajous(a, b, delta, t_max, dt):
    t = np.arange(0, t_max, dt)
    x, y = lissajous(a, b, delta, t)
    plt.plot(x, y)
    plt.title(f"Krzywa Lissajous: a={a}, b={b}, δ={delta}")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.grid(True)
    plt.axis("equal")
    plt.show()

# %%
def lissajous(a, b, delta, t):
    x = np.sin(a * t + delta)
    y = np.sin(b * t)
    return x, y

# %%
import numpy as np
import matplotlib.pyplot as plt

# częstotliwość drgań pionowych
a = 3
# częstotliwość drgań poziomych
b = 30
# faza przesunięcia
delta = np.pi / 5

# czas - w przypadku drgań sinusoidalnych, pełny okres drgań występuje w zakresie od 0 do 2π. 
t_max = 2 * np.pi
# krok czasowy (dokładność)
dt = 0.01 

draw_lissajous(a, b, delta, t_max, dt)
